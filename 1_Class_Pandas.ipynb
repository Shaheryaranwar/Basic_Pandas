# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 2.1.4

# %% [markdown]
# ## Two main type of DataType

# %%
#1 Series 1 demension
series = pd.Series(["BMW","Range Rover","Audi","Mercedes","Honda","Toyta",'Nissan'])
series
# Out:
# 0            BMW
# 1    Range Rover
# 2           Audi
# 3       Mercedes
# 4          Honda
# 5          Toyta
# 6         Nissan
# dtype: object

# %%
colors = pd.Series(['Black','Silver','White','Red','Jet-Black','Yellow','Royal Blue'])
colors
# Out:
# 0         Black
# 1        Silver
# 2         White
# 3           Red
# 4     Jet-Black
# 5        Yellow
# 6    Royal Blue
# dtype: object

# %% [markdown]
# ## Create DataFrame 2-demensional

# %%
car_data = pd.DataFrame({'Car-Maker': series ,'Color': colors})
car_data
# Out:
#      Car-Maker       Color
# 0          BMW       Black
# 1  Range Rover      Silver
# 2         Audi       White
# 3     Mercedes         Red
# 4        Honda   Jet-Black
# 5        Toyta      Yellow
# 6       Nissan  Royal Blue

# %% [markdown]
# ## Importing Data

# %%
car_data = pd.read_csv('car-sales.csv')
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## important Note !
# row axis= 0
# column axis = 1

# %%
#Adding new Column in cvs file 
car_data['Pakistani Currency']=['1119200.00','1399000.00','1958600.00','6155600.00','979300.00','1259100.00','2098500.00','1958600.00','1748750.00','2714060.00'
                               ]
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00
# 5  Toyota  Green          99213      4   $4,500.00         1259100.00
# 6   Honda   Blue          45698      4   $7,500.00         2098500.00
# 7   Honda   Blue          54738      4   $7,000.00         1958600.00
# 8  Toyota  White          60000      4   $6,250.00         1748750.00
# 9  Nissan  White          31600      4   $9,700.00         2714060.00

# %% [markdown]
# ## Exporting DataFrame

# %%
car_data.to_csv('modified_car_sale.csv', index=False)

# %%
modified_car_sale = pd.read_csv('modified_car_sale.csv')
modified_car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00           1119200.0
# 1   Honda    Red          87899      4   $5,000.00           1399000.0
# 2  Toyota   Blue          32549      3   $7,000.00           1958600.0
# 3     BMW  Black          11179      5  $22,000.00           6155600.0
# 4  Nissan  White         213095      4   $3,500.00            979300.0
# 5  Toyota  Green          99213      4   $4,500.00           1259100.0
# 6   Honda   Blue          45698      4   $7,500.00           2098500.0
# 7   Honda   Blue          54738      4   $7,000.00           1958600.0
# 8  Toyota  White          60000      4   $6,250.00           1748750.0
# 9  Nissan  White          31600      4   $9,700.00           2714060.0

# %% [markdown]
# ## Describing Data

# %%
#Attribute 
car_data.dtypes
#Function
# car_data.to_csv()
# Out:
# Make                  object
# Colour                object
# Odometer (KM)          int64
# Doors                  int64
# Price                 object
# Pakistani Currency    object
# dtype: object

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price',
#        'Pakistani Currency'],
#       dtype='object')

# %%
car_columns = car_data.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price',
#        'Pakistani Currency'],
#       dtype='object')

# %%
car_data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00
# 5  Toyota  Green          99213      4   $4,500.00         1259100.00
# 6   Honda   Blue          45698      4   $7,500.00         2098500.00
# 7   Honda   Blue          54738      4   $7,000.00         1958600.00
# 8  Toyota  White          60000      4   $6,250.00         1748750.00
# 9  Nissan  White          31600      4   $9,700.00         2714060.00

# %%
car_data.describe()
#describe work only numeric column
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_data.info()
#index combine with dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                10 non-null     object
#  1   Colour              10 non-null     object
#  2   Odometer (KM)       10 non-null     int64
#  3   Doors               10 non-null     int64
#  4   Price               10 non-null     object
#  5   Pakistani Currency  10 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 608.0+ bytes

# %%
car_data.sum()
# Out:
# Make                  ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour                    WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                                    786014
# Doors                                                                40
# Price                 $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# Pakistani Currency    1119200.001399000.001958600.006155600.00979300...
# dtype: object

# %%
len(car_data)
# Out:
# 10

# %%
car_data["Doors"].sum()
# Out:
# 40

# %%
car_data["Pakistani Currency"].sum()
# Out:
# '1119200.001399000.001958600.006155600.00979300.001259100.002098500.001958600.001748750.002714060.00'

# %% [markdown]
# ## Veiwing and Selecting Data

# %%
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00

# %%
car_data.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price Pakistani Currency
# 5  Toyota  Green          99213      4  $4,500.00         1259100.00
# 6   Honda   Blue          45698      4  $7,500.00         2098500.00
# 7   Honda   Blue          54738      4  $7,000.00         1958600.00
# 8  Toyota  White          60000      4  $6,250.00         1748750.00
# 9  Nissan  White          31600      4  $9,700.00         2714060.00

# %%
car_data.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00
# 5  Toyota  Green          99213      4   $4,500.00         1259100.00
# 6   Honda   Blue          45698      4   $7,500.00         2098500.00
# 7   Honda   Blue          54738      4   $7,000.00         1958600.00
# 8  Toyota  White          60000      4   $6,250.00         1748750.00
# 9  Nissan  White          31600      4   $9,700.00         2714060.00

# %% [markdown]
# ## loc and Iloc

# %%
players = pd.Series(['Babar Azam', 'Rizwan', 'Muhammad Amir', 'M.Haris', 'Iftkhar', 'Shane Watson'], index=[7, 4, 3, 6,8,9])
players
# Out:
# 7       Babar Azam
# 4           Rizwan
# 3    Muhammad Amir
# 6          M.Haris
# 8          Iftkhar
# 9     Shane Watson
# dtype: object

# %%
players.loc[8]
# Out:
# 'Iftkhar'

# %%
players.loc[::-1]#it reverse the main list index value
# Out:
# 9     Shane Watson
# 8          Iftkhar
# 6          M.Haris
# 3    Muhammad Amir
# 4           Rizwan
# 7       Babar Azam
# dtype: object

# %%
car_data.iloc[3]
# Out:
# Make                         BMW
# Colour                     Black
# Odometer (KM)              11179
# Doors                          5
# Price                 $22,000.00
# Pakistani Currency    6155600.00
# Name: 3, dtype: object

# %%
players
# Out:
# 7       Babar Azam
# 4           Rizwan
# 3    Muhammad Amir
# 6          M.Haris
# 8          Iftkhar
# 9     Shane Watson
# dtype: object

# %%
players.iloc[5]#it reffer the index num by deafualt
# Out:
# 'Shane Watson'

# %%
car_data.iloc[5]#it reffer the index num by deafualt
# Out:
# Make                      Toyota
# Colour                     Green
# Odometer (KM)              99213
# Doors                          4
# Price                  $4,500.00
# Pakistani Currency    1259100.00
# Name: 5, dtype: object

# %%
car_data.iloc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00

# %%
car_data['Pakistani Currency']
# Out:
# 0    1119200.00
# 1    1399000.00
# 2    1958600.00
# 3    6155600.00
# 4     979300.00
# 5    1259100.00
# 6    2098500.00
# 7    1958600.00
# 8    1748750.00
# 9    2714060.00
# Name: Pakistani Currency, dtype: object

# %%
car_data['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_data.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data[car_data['Colour']=='Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price Pakistani Currency
# 2  Toyota   Blue          32549      3  $7,000.00         1958600.00
# 6   Honda   Blue          45698      4  $7,500.00         2098500.00
# 7   Honda   Blue          54738      4  $7,000.00         1958600.00

# %%
car_data[car_data['Pakistani Currency'] > '400000']
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00

# %% [markdown]
# ## Compairing two Column

# %%
pd.crosstab(car_data['Make'],car_data['Doors'])#corrstab come in
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Pakistani Currency
# 0  Toyota  White         150043      4   $4,000.00         1119200.00
# 1   Honda    Red          87899      4   $5,000.00         1399000.00
# 2  Toyota   Blue          32549      3   $7,000.00         1958600.00
# 3     BMW  Black          11179      5  $22,000.00         6155600.00
# 4  Nissan  White         213095      4   $3,500.00          979300.00
# 5  Toyota  Green          99213      4   $4,500.00         1259100.00
# 6   Honda   Blue          45698      4   $7,500.00         2098500.00
# 7   Honda   Blue          54738      4   $7,000.00         1958600.00
# 8  Toyota  White          60000      4   $6,250.00         1748750.00
# 9  Nissan  White          31600      4   $9,700.00         2714060.00

# %%
car_data.dtypes
# Out:
# Make                  object
# Colour                object
# Odometer (KM)          int64
# Doors                  int64
# Price                 object
# Pakistani Currency    object
# dtype: object

# %%
#group By if we want to compair two or more columns
car_data.groupby(["Make"]).sum()
# Out:
#                      Colour  Odometer (KM)  Doors  \
# Make
# BMW                   Black          11179      5
# Honda           RedBlueBlue         188335     12
# Nissan           WhiteWhite         244695      8
# Toyota  WhiteBlueGreenWhite         341805     15
#
#                                        Price  \
# Make
# BMW                               $22,000.00
# Honda            $5,000.00$7,500.00$7,000.00
# Nissan                    $3,500.00$9,700.00
# Toyota  $4,000.00$7,000.00$4,500.00$6,250.00
#
#                               Pakistani Currency
# Make
# BMW                                   6155600.00
# Honda             1399000.002098500.001958600.00
# Nissan                       979300.002714060.00
# Toyota  1119200.001958600.001259100.001748750.00

# %% [markdown]
# ## Visualizing the Graphs on Data

# %%
# %matplotlib inline
import matplotlib.pyplot as pyplt

# %%
car_data["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
#histogram this is the great way to disturibution 
car_data["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_data["Pakistani Currency"].hist()
# Out:
# <Axes: >

# %%
## Showing datatype of column
car_data['Price'].dtype# its means its object histogram or ploting shows only for numeric columns
# Out:
# dtype('O')

# %%
car_data['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## converting some data type / symbols  into int type

# %%
car_data['Price'] = car_data['Price'].str.replace('[\$\,\.]', '', regex=True).astype('float').astype('Int64')

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency
# 0  Toyota  White         150043      4   400000         1119200.00
# 1   Honda    Red          87899      4   500000         1399000.00
# 2  Toyota   Blue          32549      3   700000         1958600.00
# 3     BMW  Black          11179      5  2200000         6155600.00
# 4  Nissan  White         213095      4   350000          979300.00
# 5  Toyota  Green          99213      4   450000         1259100.00
# 6   Honda   Blue          45698      4   750000         2098500.00
# 7   Honda   Blue          54738      4   700000         1958600.00
# 8  Toyota  White          60000      4   625000         1748750.00
# 9  Nissan  White          31600      4   970000         2714060.00

# %% [markdown]
# ## Manipulating Data

# %%
car_data['Make'].str.lower() #it did not change the orginal datd
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency
# 0  Toyota  White         150043      4   400000         1119200.00
# 1   Honda    Red          87899      4   500000         1399000.00
# 2  Toyota   Blue          32549      3   700000         1958600.00
# 3     BMW  Black          11179      5  2200000         6155600.00
# 4  Nissan  White         213095      4   350000          979300.00
# 5  Toyota  Green          99213      4   450000         1259100.00
# 6   Honda   Blue          45698      4   750000         2098500.00
# 7   Honda   Blue          54738      4   700000         1958600.00
# 8  Toyota  White          60000      4   625000         1748750.00
# 9  Nissan  White          31600      4   970000         2714060.00

# %%
# For do this we use = operator
car_data['Make'] = car_data['Make'].str.lower()
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency
# 0  toyota  White         150043      4   400000         1119200.00
# 1   honda    Red          87899      4   500000         1399000.00
# 2  toyota   Blue          32549      3   700000         1958600.00
# 3     bmw  Black          11179      5  2200000         6155600.00
# 4  nissan  White         213095      4   350000          979300.00
# 5  toyota  Green          99213      4   450000         1259100.00
# 6   honda   Blue          45698      4   750000         2098500.00
# 7   honda   Blue          54738      4   700000         1958600.00
# 8  toyota  White          60000      4   625000         1748750.00
# 9  nissan  White          31600      4   970000         2714060.00

# %% [markdown]
# ## Working the Missing data

# %%
car_missing_data = pd.read_csv('car-sales-missing-data.csv')
car_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# we use fillna function to fill the non values in our dataset

# %%
car_missing_data['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_missing_data['Odometer'].fillna(car_missing_data['Odometer'].mean(), inplace=True)

# %%
car_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#dropna just remove the missing columns 
car_missing_data.dropna(inplace=True)
car_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_missing_data.to_csv('car_missing_data_dropped.csv')

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency
# 0  toyota  White         150043      4   400000         1119200.00
# 1   honda    Red          87899      4   500000         1399000.00
# 2  toyota   Blue          32549      3   700000         1958600.00
# 3     bmw  Black          11179      5  2200000         6155600.00
# 4  nissan  White         213095      4   350000          979300.00
# 5  toyota  Green          99213      4   450000         1259100.00
# 6   honda   Blue          45698      4   750000         2098500.00
# 7   honda   Blue          54738      4   700000         1958600.00
# 8  toyota  White          60000      4   625000         1748750.00
# 9  nissan  White          31600      4   970000         2714060.00

# %% [markdown]
# ## Add new columns through series dataFrame method

# %%
#column from series 
seats_car = pd.Series([5,5,5,5,5])
#new column called seats 
car_data["Seats"] = seats_car
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    NaN
# 6   honda   Blue          45698      4   750000         2098500.00    NaN
# 7   honda   Blue          54738      4   700000         1958600.00    NaN
# 8  toyota  White          60000      4   625000         1748750.00    NaN
# 9  nissan  White          31600      4   970000         2714060.00    NaN

# %%
car_data["Seats"].fillna(5, inplace=True)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    5.0
# 6   honda   Blue          45698      4   750000         2098500.00    5.0
# 7   honda   Blue          54738      4   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 9  nissan  White          31600      4   970000         2714060.00    5.0

# %% [markdown]
# ## Add column from python list

# %%
fuel_economy = [10.53,9.7,9.76,8.5,10.12,11.01,9.01,8.99,10.35,9.112]
wheel = [4,4,4,4,4,4,4,4,4,4]
car_data['Fuel Average Per 100km']= fuel_economy
car_data["Wheels"]=wheel
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    5.0
# 6   honda   Blue          45698      4   750000         2098500.00    5.0
# 7   honda   Blue          54738      4   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 9  nissan  White          31600      4   970000         2714060.00    5.0
#
#    Fuel Average Per 100km  Wheels
# 0                  10.530       4
# 1                   9.700       4
# 2                   9.760       4
# ...

# %%
car_data['Total Fuel Use']=car_data['Odometer (KM)']/100*car_data["Fuel Average Per 100km"]
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    5.0
# 6   honda   Blue          45698      4   750000         2098500.00    5.0
# 7   honda   Blue          54738      4   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 9  nissan  White          31600      4   970000         2714060.00    5.0
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use
# 0                  10.530       4      15799.5279
# 1                   9.700       4       8526.2030
# ...

# %% [markdown]
# ## Create a Column from single value

# %%
car_data["Road Safety Test Passed"] = True
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    5.0
# 6   honda   Blue          45698      4   750000         2098500.00    5.0
# 7   honda   Blue          54738      4   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 9  nissan  White          31600      4   970000         2714060.00    5.0
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use  Road Safety Test Passed
# 0                  10.530       4      15799.5279                     True
# ...

# %%
car_data.dtypes
# Out:
# Make                        object
# Colour                      object
# Odometer (KM)                int64
# Doors                        int64
# Price                        Int64
# Pakistani Currency          object
# Seats                      float64
# Fuel Average Per 100km     float64
# Wheels                       int64
# Total Fuel Use             float64
# Road Safety Test Passed       bool
# dtype: object

# %% [markdown]
# ## Removing column

# %%
car_data.drop('Seats',axis=1)#Drop is function so use ()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  \
# 0  toyota  White         150043      4   400000         1119200.00
# 1   honda    Red          87899      4   500000         1399000.00
# 2  toyota   Blue          32549      3   700000         1958600.00
# 3     bmw  Black          11179      5  2200000         6155600.00
# 4  nissan  White         213095      4   350000          979300.00
# 5  toyota  Green          99213      4   450000         1259100.00
# 6   honda   Blue          45698      4   750000         2098500.00
# 7   honda   Blue          54738      4   700000         1958600.00
# 8  toyota  White          60000      4   625000         1748750.00
# 9  nissan  White          31600      4   970000         2714060.00
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use  Road Safety Test Passed
# 0                  10.530       4      15799.5279                     True
# 1                   9.700       4       8526.2030                     True
# ...

# %% [markdown]
# ## Shuffled the data

# %%
car_shuffled_data = car_data.sample(frac=1)
car_shuffled_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 4  nissan  White         213095      4   350000          979300.00    5.0
# 0  toyota  White         150043      4   400000         1119200.00    5.0
# 1   honda    Red          87899      4   500000         1399000.00    5.0
# 9  nissan  White          31600      4   970000         2714060.00    5.0
# 7   honda   Blue          54738      4   700000         1958600.00    5.0
# 6   honda   Blue          45698      4   750000         2098500.00    5.0
# 5  toyota  Green          99213      4   450000         1259100.00    5.0
# 2  toyota   Blue          32549      3   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 3     bmw  Black          11179      5  2200000         6155600.00    5.0
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use  Road Safety Test Passed
# 4                  10.120       4      21565.2140                     True
# ...

# %% [markdown]
# ## Rest the index of Shuffle

# %%
car_shuffled_data.reset_index(drop=True , inplace=True)

# %%
car_shuffled_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 0  nissan  White         213095      4   350000          979300.00    5.0
# 1  toyota  White         150043      4   400000         1119200.00    5.0
# 2   honda    Red          87899      4   500000         1399000.00    5.0
# 3  nissan  White          31600      4   970000         2714060.00    5.0
# 4   honda   Blue          54738      4   700000         1958600.00    5.0
# 5   honda   Blue          45698      4   750000         2098500.00    5.0
# 6  toyota  Green          99213      4   450000         1259100.00    5.0
# 7  toyota   Blue          32549      3   700000         1958600.00    5.0
# 8  toyota  White          60000      4   625000         1748750.00    5.0
# 9     bmw  Black          11179      5  2200000         6155600.00    5.0
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use  Road Safety Test Passed
# 0                  10.120       4      21565.2140                     True
# ...

# %%
# Revalue the column all values
car_data["Odometer (KM)"]=car_data["Odometer (KM)"].apply(lambda x:x/1.6)
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Pakistani Currency  Seats  \
# 0  toyota  White      93776.875      4   400000         1119200.00    5.0
# 1   honda    Red      54936.875      4   500000         1399000.00    5.0
# 2  toyota   Blue      20343.125      3   700000         1958600.00    5.0
# 3     bmw  Black       6986.875      5  2200000         6155600.00    5.0
# 4  nissan  White     133184.375      4   350000          979300.00    5.0
# 5  toyota  Green      62008.125      4   450000         1259100.00    5.0
# 6   honda   Blue      28561.250      4   750000         2098500.00    5.0
# 7   honda   Blue      34211.250      4   700000         1958600.00    5.0
# 8  toyota  White      37500.000      4   625000         1748750.00    5.0
# 9  nissan  White      19750.000      4   970000         2714060.00    5.0
#
#    Fuel Average Per 100km  Wheels  Total Fuel Use  Road Safety Test Passed
# 0                  10.530       4      15799.5279                     True
# ...
